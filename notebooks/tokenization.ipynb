# %% [markdown]
# ### Tokenization

# %%
corpus = """This is a sample corpus of text that we will use for our analysis. It contains multiple sentences, and we will be performing various operations on it, such as tokenization, frequency analysis, and more. The goal is to demonstrate how to process and analyze text data effectively."""

# %%
print(corpus)
# Out:
# This is a sample corpus of text that we will use for our analysis. It contains multiple sentences, and we will be performing various operations on it, such as tokenization, frequency analysis, and more. The goal is to demonstrate how to process and analyze text data effectively.

# %% [markdown]
# ### Paragraphs -> Sentence

# %%
import ssl
import nltk

ssl._create_default_https_context = ssl._create_unverified_context

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/devanshsharma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/devanshsharma/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# This is a sample corpus of text that we will use for our analysis.
# It contains multiple sentences, and we will be performing various operations on it, such as tokenization, frequency analysis, and more.
# The goal is to demonstrate how to process and analyze text data effectively.

# %% [markdown]
# ### Next Tokenization, convert paragraph into words and sentence into words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'of',
#  'text',
#  'that',
#  'we',
#  'will',
#  'use',
#  'for',
#  'our',
#  'analysis',
#  '.',
#  'It',
#  'contains',
#  'multiple',
#  'sentences',
#  ',',
#  'and',
#  'we',
#  'will',
#  'be',
#  'performing',
#  'various',
#  'operations',
#  'on',
#  'it',
#  ',',
#  'such',
#  'as',
#  'tokenization',
#  ',',
#  'frequency',
#  'analysis',
#  ',',
#  'and',
#  'more',
#  '.',
#  'The',
#  'goal',
#  'is',
#  'to',
#  'demonstrate',
#  'how',
#  'to',
#  'process',
#  'and',
#  'analyze',
#  'text',
#  'data',
#  'effectively',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'of', 'text', 'that', 'we', 'will', 'use', 'for', 'our', 'analysis', '.']
# ['It', 'contains', 'multiple', 'sentences', ',', 'and', 'we', 'will', 'be', 'performing', 'various', 'operations', 'on', 'it', ',', 'such', 'as', 'tokenization', ',', 'frequency', 'analysis', ',', 'and', 'more', '.']
# ['The', 'goal', 'is', 'to', 'demonstrate', 'how', 'to', 'process', 'and', 'analyze', 'text', 'data', 'effectively', '.']

# %% [markdown]
# ### tree bank tokenizer

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'of',
#  'text',
#  'that',
#  'we',
#  'will',
#  'use',
#  'for',
#  'our',
#  'analysis.',
#  'It',
#  'contains',
#  'multiple',
#  'sentences',
#  ',',
#  'and',
#  'we',
#  'will',
#  'be',
#  'performing',
#  'various',
#  'operations',
#  'on',
#  'it',
#  ',',
#  'such',
#  'as',
#  'tokenization',
#  ',',
#  'frequency',
#  'analysis',
#  ',',
#  'and',
#  'more.',
#  'The',
#  'goal',
#  'is',
#  'to',
#  'demonstrate',
#  'how',
#  'to',
#  'process',
#  'and',
#  'analyze',
#  'text',
#  'data',
#  'effectively',
#  '.']

# %% [markdown]
# ### STEMMING

# %%
words= ["eating", "eaten", "eat", "eats", "writing", "written", "write", "writes", "swimming", "swum", "swim", "swims"]

# %% [markdown]
# ### PortnerStemmer -> Stemming technique

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"--->"+stemming.stem(word))
# Out:
# eating--->eat
# eaten--->eaten
# eat--->eat
# eats--->eat
# writing--->write
# written--->written
# write--->write
# writes--->write
# swimming--->swim
# swum--->swum
# swim--->swim
# swims--->swim

# %% [markdown]
# ### RegexpStemmer Class

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# ### Snowball stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer =  SnowballStemmer('english')

# %%
for word in words:
    print(word+"--->"+snowballstemmer.stem(word))
# Out:
# eating--->eat
# eaten--->eaten
# eat--->eat
# eats--->eat
# writing--->write
# written--->written
# write--->write
# writes--->write
# swimming--->swim
# swum--->swum
# swim--->swim
# swims--->swim

# %% [markdown]
# ### Wordnet Lemmatizer

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/devanshsharma/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/devanshsharma/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("going", pos='v')
# Out:
# 'go'

# %%
words = ["eating", "eaten", "eat", "eats", "writing", "written", "write", "writes", "swimming", "swum", "swim", "swims"]

# %%
for word in words:
    print( word + "---->" + lemmatizer.lemmatize(word, pos='v'))
# Out:
# eating---->eat
# eaten---->eat
# eat---->eat
# eats---->eat
# writing---->write
# written---->write
# write---->write
# writes---->write
# swimming---->swim
# swum---->swim
# swim---->swim
# swims---->swim

# %%
lemmatizer.lemmatize("goes")
# Out:
# 'go'
